# %% [markdown]
# My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b> Nithin Narla </b>
#
#
# Currently working as a SQL Developer. Aspiring to be a Data Scientist

# %% [markdown]
# <i> I am interested in Data Science because I love to study and tame the data in real life

# %% [markdown]
# <H3> The below code computes a while loop </H3>

# %%
counter=0
while counter<10:
    print('IBM Watson Studio',counter)
    counter=counter+1
# Out:
# IBM Watson Studio 0
# IBM Watson Studio 1
# IBM Watson Studio 2
# IBM Watson Studio 3
# IBM Watson Studio 4
# IBM Watson Studio 5
# IBM Watson Studio 6
# IBM Watson Studio 7
# IBM Watson Studio 8
# IBM Watson Studio 9

# %% [markdown]
# www.ibm.com
#
# 1.
# 2.
# 3.
# 4.
# 5.
#
# Nithin <br> Narla
#
# ![Silicon%20Valley.jpg](attachment:Silicon%20Valley.jpg)
